# %%
import numpy as np 
import pandas as pd
import seaborn as sn

# %%
# Load Netflix csv data into noteboom
df=pd.read_csv(r'C:\Users\Vinay Kr Choudhary\OneDrive\Desktop\Data_Set/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Check the size of the data 
df.size
# Out:
# 105684

# %%
# check how many rows and column in the data 
df.shape
# Out:
# (8807, 12)

# %%
#Check  how which type of columns and how many non=null columns in the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Check how many null value in the data and which column contain how much null value
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# check percentage of null_value in the column 
missing_percentage=df.isnull().mean()*100
missing_percentage
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
# check which column contain more than 10% of the null value
missing_percentage[missing_percentage>10]
# Out:
# director    29.908028
# dtype: float64

# %%
import sqlalchemy as sal

engine = sal.create_engine(
    r"mssql://DESKTOP-EU084GF\SQLEXPRESS/PRACTICE?driver=ODBC+DRIVER+17+FOR+SQL+SERVER"
)
conn = engine.connect()

# %%
df.to_sql(
    'netflix_raw',
    con=conn,
    index=False,
    if_exists='append'   # ✅ correct spelling
)
conn.close()

# %%
# max lenght For all columns
max_lengths = df.astype(str).map(len).max()
print(max_lengths)
# Out:
# show_id           5
# type              7
# title           104
# director        208
# cast            771
# country         123
# date_added       19
# release_year      4
# rating            8
# duration         10
# listed_in        79
# description     248
# dtype: int64

# %%
max(df.title.dropna().str.len())
# Out:
# 104

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
